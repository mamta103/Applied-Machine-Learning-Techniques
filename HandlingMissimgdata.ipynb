# %%
import pandas as pd
import numpy as np

# %%
data = [['John', 25, 65], ['David', 15, 45], ['Alice', 70, 75], ['Bob', 20]]

# %%
df=pd.DataFrame(data, columns=['Name', 'Age', 'Weight'])

# %%
df
# Out:
#     Name  Age  Weight
# 0   John   25    65.0
# 1  David   15    45.0
# 2  Alice   70    75.0
# 3    Bob   20     NaN

# %%
df.info() #to find rely to get NAN impt
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Weight  3 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
df.isnull() #total null value
# Out:
#     Name    Age  Weight
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False    True

# %%
df.isnull().sum() #Total Missing values
# Out:
# Name      0
# Age       0
# Weight    1
# dtype: int64

# %%
#Drop the entire Row
df1= df.dropna()
df1
# Out:
#     Name  Age  Weight
# 0   John   25    65.0
# 1  David   15    45.0
# 2  Alice   70    75.0

# %%
df1.describe()
# Out:
#              Age     Weight
# count   3.000000   3.000000
# mean   36.666667  61.666667
# std    29.297326  15.275252
# min    15.000000  45.000000
# 25%    20.000000  55.000000
# 50%    25.000000  65.000000
# 75%    47.500000  70.000000
# max    70.000000  75.000000

# %% [markdown]
# #substring with another value typically with mean median and mode and this method called Imputation

# %% [markdown]
# df.describe

# %%
from sklearn.impute import SimpleImputer

# %%
imputer= SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
imputer= imputer.fit(df[['Weight']])

# %%
df['Weight']=imputer.transform(df[['Weight']])

# %%
df
# Out:
#     Name  Age     Weight
# 0   John   25  65.000000
# 1  David   15  45.000000
# 2  Alice   70  75.000000
# 3    Bob   20  61.666667

# %%
data = [['John', 25, 65], ['David', 15, 45], ['Alice', 70, 75], ['Bob', 20]]
df2 = pd.DataFrame(data, columns=['Name','Age','Weight'])
df2['Weight']= df['Weight'].fillna(df2['Weight'].mean())

# %%
df2
# Out:
#     Name  Age     Weight
# 0   John   25  65.000000
# 1  David   15  45.000000
# 2  Alice   70  75.000000
# 3    Bob   20  61.666667

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df['Age'])
plt.title('Age Outliers Detection')
plt.show()
